# %% [markdown]
#     109p
#         머신러닝과 딥러닝의 차이
#                 머신러닝은 데이터의 특성을 추출하는 과정이 필요
#                 딥러닝은 데이터의 특성을 추출하는 과정이 필요 없음
#
#     강화 학습
#         학습 과정에서 결과에 따라 보상을 주면서 학습의 방향을 결정
#     지도 학습
#         레이블이 있는 데이터를 학습시키는 방법
#
#     data collectioon
#     preprocessing
#     model
#     model train
#     model test
#     model validation
#
#     훈련과 테스트를 나누는 이유는 모델의 일반화 성능을 평가하기 위해서
#
#     과적합
#         특정 데이터에서만 성능이 좋음
#         모델을 단순하게
#
#     122p
#
#     131p
#         marco avg 성능 평균 계산
#         weight avg 데이터 수에 대해서 가중치를 부여하여 성능 평균 계산
#
#     148p 150p
#         경사하강법
#             최적화 함수 알고리즘 하나
#
#     퍼셉트론
#         173p 182p 187p
#         192p
#
#     MLP
#         다중 퍼셉트론
#             하나의 퍼셉트론으로는 XOR 구분을 하지 못함
#
#         196p
#         202p
#         215p
#         211p
#
#     역전파
#         224p
#
#     256p
#     262p
#         시퀀스와 Add 사용
#         함수 형태로
#         클래스 형로로
#
#     282p
#     301p
#         기울기 소실
#             네트워크 레이어가 많아질 수록 역전파를 진행할 경우 출력층에서 멀어질수록 기울기가 작아져 갱신이 안되는 경우
#             시그모이드 함수를 변경하여 양수는 제한없이 그대로 출력하는 방법 사용
#
#
#     312p
#     305p
#     334p
#
#     과적합
#         조기 종료
#         가중치 규제
#         학습 과정에서는 랜덤으로 일부의 노드를 제외하고 학습하고 테스트 과정에서는 포함함
#
#     과소 적합
#         데이터 증가
